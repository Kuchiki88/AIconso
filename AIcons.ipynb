# %%
# !./darknet detect cfg/yolov3.cfg yolov3-voc_900.weights /Users/toshikifukui/Desktop/AIC_物体認識/1-1/正解画像/correct_pic_0820.jpg
import glob

# %%
# !export DISPLAY=:0.0

# %%
!--display 0
# Out:
# /bin/bash: --: invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option

# %%
! export DISPLAY=$(cat /etc/resolv.conf | grep nameserver | awk '{print $2}'):0

# %%
import os
import cv2

# %%
os.listdir()
# Out:
# ['data',
#  'Untitled0.ipynb',
#  'yolov3.weights',
#  'darknet53.conv.74',
#  '.git',
#  '.gitignore',
#  'LICENSE',
#  'LICENSE.fuck',
#  'LICENSE.gen',
#  'LICENSE.gpl',
#  'LICENSE.meta',
#  'LICENSE.mit',
#  'LICENSE.v1',
#  'README.md',
#  'cfg',
#  'examples',
#  'include',
#  'python',
#  'scripts',
#  'src',
#  'obj',
#  'backup',
#  'results',
#  'yolov3.weights.1',
#  'yolov3.weights.2',
#  'darknet53.conv.74.1',
#  'darknet53.conv.74.2',
#  'predictions.jpg',
#  'Makefile',
#  'train.txt',
#  'test.txt',
#  '01-01.mp4',
#  'libdarknet.so',
#  'libdarknet.a',
#  'darknet']

# %%
# !make clean
# Out:
# rm -rf ./obj/gemm.o ./obj/utils.o ./obj/cuda.o ./obj/deconvolutional_layer.o ./obj/convolutional_layer.o ./obj/list.o ./obj/image.o ./obj/activations.o ./obj/im2col.o ./obj/col2im.o ./obj/blas.o ./obj/crop_layer.o ./obj/dropout_layer.o ./obj/maxpool_layer.o ./obj/softmax_layer.o ./obj/data.o ./obj/matrix.o ./obj/network.o ./obj/connected_layer.o ./obj/cost_layer.o ./obj/parser.o ./obj/option_list.o ./obj/detection_layer.o ./obj/route_layer.o ./obj/upsample_layer.o ./obj/box.o ./obj/normalization_layer.o ./obj/avgpool_layer.o ./obj/layer.o ./obj/local_layer.o ./obj/shortcut_layer.o ./obj/logistic_layer.o ./obj/activation_layer.o ./obj/rnn_layer.o ./obj/gru_layer.o ./obj/crnn_layer.o ./obj/demo.o ./obj/batchnorm_layer.o ./obj/region_layer.o ./obj/reorg_layer.o ./obj/tree.o ./obj/lstm_layer.o ./obj/l2norm_layer.o ./obj/yolo_layer.o ./obj/iseg_layer.o ./obj/image_opencv.o ./obj/convolutional_kernels.o ./obj/deconvolutional_kernels.o ./obj/activation_kernels.o ./obj/im2col_kernels.o ./obj
# ...

# %%
os.chdir("/content/drive/Shared drives/AIコンソーシアム/AIC_物体検出/Yolo_環境構築/darknet") #カレントディレクトリを変更
# !make
# Out:
# gcc -Iinclude/ -Isrc/ -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -DCUDNN  -Wall -Wno-unused-result -Wno-unknown-pragmas -Wfatal-errors -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘time_gpu’:
# ./src/gemm.c:232:9: warning: ‘cudaThreadSynchronize’ is deprecated [-Wdeprecated-declarations]
#          cudaThreadSynchronize();
#          ^~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:11,
#                  from ./src/utils.h:5,
#                  from ./src/gemm.c:2:
# /usr/local/cuda/include/cuda_runtime_api.h:957:57: note: declared here
#  extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaThreadSynchronize(void);
#                                                          ^~~~~~~~~~~~~~~~~~~~~
# ...

# %%
# !pkg-config --modversion opencv
# Out:
# 3.2.0

# %%
# !pip install --upgrade opencv-python==3.4.0.12
# Out:
# Requirement already up-to-date: opencv-python==3.4.0.12 in /usr/local/lib/python3.6/dist-packages (3.4.0.12)
# ...

# %%
# !./darknet detector test cfg/obj.data cfg/yolov3-voc.cfg backup/yolov3-voc_800.weights data/annotation済み/correct_pic_0829.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32  0.177 BFLOPs
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     4 res    1                 208 x 208 x  64   ->   208 x 208 x  64
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     8 res    5                 104 x 104 x 128   ->   104 x 104 x 128
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#    10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
# ...

# %%
# !./darknet detect cfg/obj.data cfg/yolov3-voc.cfg backup/yolov3-voc_800.weights "01-01.mp4"

# %%
from google.colab.patches import cv2_imshow
img = cv2.imread("/content/drive/Shared drives/AIコンソーシアム/AIC_物体検出/Yolo_環境構築/darknet/predictions.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F73A9206B00>

# %%
# !pip install pkgconfig

# %%
! vim Makefile
# Out:
# /bin/bash: vim: command not found

# %%
# !./darknet detector test cfg/obj.data cfg/yolov3.cfg backup/yolov3-voc_900.weights "/content/drive/Shared drives/AIコンソーシアム/AIC_物体検出/1-1/正解画像/正解データ_画像/correct_pic_0004.jpg"
# Out:
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     2 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32  0.379 BFLOPs
#     3 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64  3.407 BFLOPs
#     4 res    1                 304 x 304 x  64   ->   304 x 304 x  64
#     5 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     6 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#     7 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
#     8 res    5                 152 x 152 x 128   ->   152 x 152 x 128
#     9 conv     64  1 x 1 / 1   152 x 152 x 128   ->   152 x 152 x  64  0.379 BFLOPs
#    10 conv    128  3 x 3 / 1   152 x 152 x  64   ->   152 x 152 x 128  3.407 BFLOPs
# ...
